# %% [markdown]
# <a href="https://colab.research.google.com/github/thewildchip/crispr-genie-lab/blob/main/efficiency/0_data_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0 Data Loading for Efficiency Model
#
# This notebook loads the CRISPR gRNA dataset and performs basic inspection.

# %%
import pandas as pd

FILE_PATH = "https://raw.githubusercontent.com/VKonstantakos/CRISPR-Deep-Learning/refs/heads/main/Data/2.%20Training%20datasets/1.%20DeepCRISPR-CNN-CRNNCrispr.csv"
df = pd.read_csv(FILE_PATH)

df
# Out:
#          chr      start        end direction           23-nt sequence  \
# 0      chr17   33469132   33469154         -  CTTGCTCGCGCAGGACGAGGCGG
# 1       chr4  184605984  184606006         -  ACATCAGGTTACCTCTACCAAGG
# 2       chr1   11736866   11736888         +  CTGATGCCAGCTAGTGGGCGAGG
# 3       chr4   25379067   25379089         +  CTGTTTCCCATCCTTCCGGGTGG
# 4      chr12   57936737   57936759         -  AATGTATGCACAGGGAACAGAGG
# ...      ...        ...        ...       ...                      ...
# 16744  chr19   54710145   54710167         +  CAACGCCCTGCTGCGGCGGCTGG
# 16745  chr19   54710220   54710242         -  CTAAGAAATCCTCTATCTTCAGG
# 16746  chr19   54710309   54710331         +  TGATCCGCCAGCGCCATATCAGG
# 16747  chr19   54710322   54710344         -  ATCCGAGGTGGTACCTGATATGG
# 16748  chr19   54711334   54711356         +  TCTCTCTGCGCTCTCCCTACGGG
#
#                           ctcf                    dnase  \
# 0      AAAAAAAAAAAAAAAAAAAAAAA  AAAAAAAAAAAAAAAAAAAAAAA
# 1      AAAAAAAAAAAAANNNNNNNNNN  AAAAAAAAAAAAAAAAAAAAAAA
# 2      AAAAAAAAAAAAAAAAAAAAAAA  AAAAAAAAAAAAAAAAAAAAAAA
# 3      AAAAAAAAAAAAAAAAAAAAAAA  AAAAAAAAAAAAAAAAAAAAAAA
# 4      AAAAAAAAAAAAAAANNNNNNNN  AAAAAAAAAAAAAAAAAAAAAAA
# ...                        ...                      ...
# 16744  NNNNNNNNNNNNNNNNNNNNNNN  AAAAAAAAAAAAAAAAAAAAAAA
# 16745  NNNNNNNNNNNNNNNNNNNNNNN  AAAAAAAAAAAAAAAAAAAAAAA
# 16746  AAAAAAAAAAAAAAAAAAAAAAA  AAAAAAAAAAAAAAAAAAAAAAA
# 16747  AAAAAAAAAAAAAAAAAAAAAAA  AAAAAAAAAAAAAAAAAAAAAAA
# 16748  NNNNNNNNNNNNNNNNNNNNNNN  AAAAAAAAAAAAAAAAAAAAAAA
#
#                        h3k4me3                     rrbs  Normalized efficacy  \
# 0      AAAAAAAAAAAAAAAAAAAAAAA  NNNNNNNNNNNNNNNNNNNNNNN             0.164020
# 1      NNNNNNNNNNNNNNNNNNNNNNN  NNNNNNNNNNNNNNNNNNNNNNN             0.311196
# 2      NNNNNNNNNNNNNNNNNNNNNNN  NNNNNNNNNNNNNNNNNNNNNNN             0.179397
# 3      AAAAAAAAAAAAAAAAAAAAAAA  NNNNNNNNNNNNNNNNAANNNNN             0.498712
# 4      NNNNNNNNNNNNNNNNNNNNNNN  NNNNNNNNNNNNNNNNNNNNNNN             0.233023
# ...                        ...                      ...                  ...
# 16744  AAAAAAAAAAAAAAAAAAAAAAA  NNNNNNNNNNNNNNNNNNNNNNN             0.287346
# 16745  AAAAAAAAAAAAAAAAAAAAAAA  NNNNNNNNNNNNNNNNNNNNNNN             0.209103
# 16746  AAAAAAAAAAAAAAAAAAAAAAA  NNNNNNNNNNNNNNNNNNNNNNN             0.061508
# 16747  AAAAAAAAAAAAAAAAAAAAAAA  NNNNNNNNNNNNNNNNNNNNNNN             0.181219
# 16748  AAAAAAAAAAAAAAAAAAAAAAA  NNNNNNNNNNNNNNNNNNNNNNN             0.045965
#
#        Efficacy
# 0             1
# 1             1
# 2             0
# 3             1
# 4             1
# ...         ...
# 16744         1
# 16745         0
# 16746         0
# 16747         0
# 16748         0
#
# [16749 rows x 11 columns]

# %%
df["direction"] = df["direction"].map({"+": 1, "-": 0})
df["direction"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 16744   NaN
# 16745   NaN
# 16746   NaN
# 16747   NaN
# 16748   NaN
# Name: direction, Length: 16749, dtype: float64
