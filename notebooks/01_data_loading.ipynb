# %% [markdown]
# <a href="https://colab.research.google.com/github/thewildchip/crispr-genie-lab/blob/main/notebooks/01_data_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Loading & Inspection
#
# This notebook loads the CRISPR gRNA dataset and performs basic inspection.
